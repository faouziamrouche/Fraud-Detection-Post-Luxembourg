# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from pandas import DataFrame
import numpy as np
import pandas
import pickle

datas = pandas.read_csv('./PCs900_LosAlamos.csv', sep=',', chunksize=30000) 
label = pandas.read_csv('./Labels.csv', sep=',')
events = pandas.read_csv('./Events.csv', sep=',')

label = label['Label']
label = label.replace(['Normal'], 1)
label= label.replace(['Malicious'], -1)
# label.describe()
j=0
test = 0

for i in datas :
    j=j+1
#     if j == 5 : continue
    if j == 3 :
        train = i
    if j == 5 : 
        test = i
        break

# %%
# label['Label'].value_counts()
# np.unique(y)
# sub_test = test[:1]
# sub_test
# sub_test.to_json(r'sub_test_1.json')

# %% [markdown]
# # Logistic PCA

# %%
test
# Out:
#                 V1         V2         V3         V4         V5         V6  \
# 120000  423.467783  29.625460  -5.159615  -7.701186   0.556817   0.458794
# 120001  423.000345  28.973454  -4.972273  -7.954094   0.964620   0.227375
# 120002  423.151425  28.556813  -4.592785  -7.873928   0.412645   0.416179
# 120003  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 120004  423.899713   7.731370  -7.200257  43.331895  20.122449   3.467971
# 120005  423.564892   2.283251  28.875348  32.338526  21.676577   0.715251
# 120006  424.775613 -19.502031  12.518246  -8.684946   3.223190  -0.681260
# 120007  425.270750 -23.672496  11.428520 -10.947172   4.421412   3.633013
# 120008  426.381351 -17.047706 -23.617200  -1.521476   5.705515   2.375717
# 120009  424.842784  -9.320096  18.464721   7.740826 -26.523642  -1.558699
# 120010  425.338656  -3.065283 -12.518573  16.619455 -26.954781  -2.349430
# 120011  426.638046  -4.003804 -12.252305  17.092632 -28.109917  -1.133525
# 120012  425.237755 -10.180486  19.964756   7.658359 -25.955723  -1.554936
# 120013  425.733627  -3.925672 -11.018539  16.536988 -26.386862  -2.345668
# 120014  425.709620 -10.342733  18.148664   7.464512 -25.511977  -1.601938
# 120015  426.205492  -4.087920 -12.834630  16.343141 -25.943116  -2.392670
# 120016  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 120017  422.916048  29.848000  -4.162850  -7.087610   0.363485   0.788012
# 120018  423.899713   7.731370  -7.200257  43.331895  20.122449   3.467971
# 120019  425.270750 -23.672496  11.428520 -10.947172   4.421412   3.633013
# 120020  426.381351 -17.047706 -23.617200  -1.521476   5.705515   2.375717
# 120021  425.969482 -16.594488 -22.202901  -2.681745   6.971683  -0.474077
# 120022  425.639531 -15.939426 -20.878705  -1.106218   5.718349 -11.065449
# 120023  425.521741 -23.202100  13.320512 -12.660927   6.614110  -0.444849
# 120024  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 120025  425.135220  -9.642840  19.218040   8.128528 -26.045190  -1.631194
# 120026  425.631092  -3.388027 -11.765255  17.007158 -26.476329  -2.421925
# 120027  424.304706 -10.034573  18.945618   7.446467 -26.083786  -2.649534
# 120028  424.800578  -3.779760 -12.037676  16.325096 -26.514925  -3.440266
# 120029  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# ...            ...        ...        ...        ...        ...        ...
# 149970  421.689872 -10.616177   6.711923  -3.648985  -4.611953  32.452217
# 149971  420.371737  -7.213352   9.509344  -2.315076  -5.504671  29.378426
# 149972  423.598105  29.880826  -4.004472  -7.806708  -0.539785   0.377218
# 149973  422.972790  29.256793  -3.792090  -7.084106   0.937931   0.203549
# 149974  423.591645  30.176219  -4.833379  -7.344205   0.064495   1.229887
# 149975  423.112934  29.949845  -4.756750  -7.287817   0.733883  -0.025377
# 149976  423.236247  29.934360  -4.537113  -6.920454   0.238380   0.570047
# 149977  423.513930  29.556778  -4.282241  -7.699030  -0.113018   0.716770
# 149978  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 149979  423.899713   7.731370  -7.200257  43.331895  20.122449   3.467971
# 149980  423.564892   2.283251  28.875348  32.338526  21.676577   0.715251
# 149981  425.412681 -15.361266 -19.142493  -1.415035   5.325256  -8.006478
# 149982  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 149983  421.957617  -8.285691  17.838115  -2.636682  -4.516852  -0.834882
# 149984  420.967823  -7.900675   8.648595  -2.758113  -4.404585  30.100619
# 149985  421.689872 -10.616177   6.711923  -3.648985  -4.611953  32.452217
# 149986  421.197392  -7.361305   8.862762  -2.747934  -5.548004  29.320531
# 149987  423.431609  -2.604579 -13.989880   7.372333  -4.528951  -2.075193
# 149988  423.402664  29.152750  -4.701823  -7.311451   0.372577   0.923559
# 149989  422.766151  29.485516  -4.477155  -7.407003   0.377190   0.696344
# 149990  423.431913  29.739481  -4.533682  -7.191448   0.149572   0.128117
# 149991  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 149992  425.412681 -15.361266 -19.142493  -1.415035   5.325256  -8.006478
# 149993  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 149994  423.591645  30.176219  -4.833379  -7.344205   0.064495   1.229887
# 149995  423.169384  29.604885  -3.982455  -7.992685  -0.062428   0.229914
# 149996  422.753149  29.747447  -3.918920  -8.021625   0.478192   0.399567
# 149997  422.645801  30.119622  -4.335629  -7.538427   0.046120   0.288849
# 149998  422.274080  29.870725  -4.891475  -7.038682   0.066278   0.871161
# 149999  422.922642  29.147294  -4.580405  -7.420026   0.394491   0.801145
#
#                V7         V8         V9        V10  ...      V891      V892  \
# 120000  -0.419309   0.157259   3.523856  -0.379059  ... -0.073519 -0.424265
# 120001  -0.871696   0.579326   3.493874  -0.320664  ...  0.696891 -1.203187
# 120002  -0.221264   0.221597   3.313026  -0.205381  ... -0.440572  0.598151
# 120003   3.793529  -1.150661 -17.610624   2.018777  ... -0.002117 -0.002911
# 120004  -2.211212   0.380687   8.654187  -0.155083  ... -0.000243  0.000941
# 120005   0.827684   0.199396  -1.958891  -0.311964  ...  0.002553 -0.000644
# 120006   1.330850   2.560317   2.927521   1.901866  ...  0.002224 -0.014424
# 120007  13.427999  18.482029   7.740488   2.577048  ... -0.000723  0.001136
# 120008  13.460242   7.659150  -6.050783 -12.354713  ...  0.005898  0.003772
# 120009   1.542247  -0.138128   2.416310  -1.932453  ...  0.022615  0.005142
# 120010   0.853042  -1.704137  -2.617677   1.050960  ...  0.021702  0.000869
# 120011  -0.939195  -1.147404  -3.078090   0.648750  ...  0.026449 -0.179534
# 120012   0.775089   0.533580   2.640919  -1.726760  ...  0.009104  0.010844
# 120013   0.085885  -1.032429  -2.393068   1.256653  ...  0.008191  0.006570
# 120014   0.130930   1.129871   2.102311  -1.785109  ...  0.000151  0.006425
# 120015  -0.558274  -0.436138  -2.931675   1.198305  ... -0.000762  0.002152
# 120016   3.793529  -1.150661 -17.610624   2.018777  ... -0.002117 -0.002911
# 120017  -0.258520   0.423882   3.335102  -1.099357  ... -0.196716  0.533273
# 120018  -2.211212   0.380687   8.654187  -0.155083  ... -0.000243  0.000941
# 120019  13.427999  18.482029   7.740488   2.577048  ... -0.000723  0.001136
# 120020  13.460242   7.659150  -6.050783 -12.354713  ...  0.005898  0.003772
# 120021   9.031975 -16.419896  -4.344690 -11.180269  ...  0.000037 -0.000859
# 120022 -18.134014   3.079128  -5.892536   7.573821  ... -0.000846 -0.001200
# 120023   6.138106 -20.230942   9.975613   6.601753  ... -0.000071  0.002581
# 120024 -18.132590   5.092236   5.776833  -9.629583  ...  0.001626  0.000456
# 120025   0.649370   0.521869   1.936716  -1.922949  ... -0.005627  0.015974
# 120026  -0.039834  -1.044139  -3.097271   1.060465  ... -0.006540  0.011700
# 120027   1.430103   0.167578   2.542604  -1.703223  ...  0.029982 -0.056676
# 120028   0.740899  -1.398431  -2.491383   1.280190  ...  0.029069 -0.060949
# 120029   3.793529  -1.150661 -17.610624   2.018777  ... -0.002117 -0.002911
# ...           ...        ...        ...        ...  ...       ...       ...
# 149970  -7.014699   9.443905  -1.888154  -1.684166  ...  0.155478 -0.264085
# 149971 -15.875666  -1.722208  -2.714925  -2.021230  ...  0.142194 -0.212017
# 149972  -0.763124   0.099511   2.757855  -0.088489  ... -0.217852  0.649912
# 149973  -0.379830   0.361677   3.188718  -0.195259  ...  0.524633 -0.006264
# 149974  -0.849924   0.235554   3.604544  -0.763383  ...  0.372000  0.817236
# 149975  -0.541249   0.034159   2.996198  -0.954567  ...  0.524482 -0.364012
# 149976  -0.385449   0.413999   3.733807  -0.332254  ...  0.446253  0.370814
# 149977  -0.521897   0.752275   3.774278  -1.051102  ...  0.091798 -0.580015
# 149978   3.793529  -1.150661 -17.610624   2.018777  ... -0.002117 -0.002911
# 149979  -2.211212   0.380687   8.654187  -0.155083  ... -0.000243  0.000941
# 149980   0.827684   0.199396  -1.958891  -0.311964  ...  0.002553 -0.000644
# 149981 -13.472704   1.739185  -2.736487   3.652695  ... -0.003118  0.007672
# 149982 -18.132590   5.092236   5.776833  -9.629583  ...  0.001626  0.000456
# 149983  -0.561170  -0.038687   2.441428  -1.135265  ...  0.394437  0.339348
# 149984 -15.970132  -1.228266  -2.777024  -2.468458  ... -1.016413 -0.864918
# 149985  -7.014699   9.443905  -1.888154  -1.684166  ...  0.155478 -0.264085
# 149986 -15.530450  -1.777652  -2.752247  -2.049012  ... -0.329110 -0.406444
# 149987  -1.241706  -1.795627  -2.868333   1.913424  ... -0.337547 -0.335062
# 149988  -0.502297   0.521353   3.236149  -0.102154  ...  0.343732 -0.346574
# 149989  -0.657880   0.818402   3.102494  -1.098302  ... -0.341826 -0.011401
# 149990  -0.588848   0.443686   3.625015   0.593497  ... -0.439545  0.750862
# 149991   3.793529  -1.150661 -17.610624   2.018777  ... -0.002117 -0.002911
# 149992 -13.472704   1.739185  -2.736487   3.652695  ... -0.003118  0.007672
# 149993 -18.132590   5.092236   5.776833  -9.629583  ...  0.001626  0.000456
# 149994  -0.849924   0.235554   3.604544  -0.763383  ...  0.372000  0.817236
# 149995  -0.503885   0.258701   3.793536   0.068856  ... -0.255245 -0.078186
# 149996  -0.413104   0.661168   3.322447  -0.191099  ...  0.023087  0.145308
# 149997  -0.177235   0.566137   3.755965  -0.308244  ... -1.159545 -0.101748
# 149998  -0.168846   0.425118   3.811248  -0.939902  ...  0.305589  0.899443
# 149999  -0.192444   0.583117   3.842441  -0.676670  ... -0.167975 -0.161247
#
#             V893      V894      V895      V896      V897      V898      V899  \
# 120000 -0.230735 -0.344972 -0.138616  0.594745  0.237645  0.363659  0.206817
# 120001  0.539852 -2.409121  0.478609 -0.670814  0.161365 -1.242325 -0.330417
# 120002 -0.184100  0.460553  0.200107  0.206779  0.003572  0.481614  0.185744
# 120003 -0.005422  0.001505 -0.000316 -0.000251 -0.002745  0.000914 -0.000115
# 120004 -0.002008 -0.001913 -0.000680 -0.000761 -0.001244 -0.001835  0.001761
# 120005  0.001846  0.000206  0.001056 -0.001992  0.000336  0.000995 -0.000925
# 120006 -0.026895  0.003003 -0.024296  0.006202  0.009796 -0.004582  0.010400
# 120007 -0.000326 -0.000279 -0.001968 -0.002086 -0.001505  0.000012  0.000026
# 120008  0.004111 -0.001919  0.004236 -0.000473  0.002308 -0.001240  0.000902
# 120009 -0.018332 -0.021937 -0.015132 -0.000345 -0.004921 -0.004828 -0.001071
# 120010 -0.017060 -0.016674 -0.010292  0.004093 -0.002867 -0.001587 -0.000108
# 120011  0.019647 -0.233980 -0.024267  0.084453  0.344383  0.060870  0.101809
# 120012 -0.014124 -0.005053 -0.007642  0.010371  0.007336  0.006547  0.009456
# 120013 -0.012852  0.000210 -0.002802  0.014809  0.009390  0.009788  0.010420
# 120014 -0.026255 -0.001704 -0.009878 -0.010406  0.008287 -0.002215 -0.003568
# 120015 -0.024983  0.003559 -0.005038 -0.005967  0.010341  0.001026 -0.002605
# 120016 -0.005422  0.001505 -0.000316 -0.000251 -0.002745  0.000914 -0.000115
# 120017  0.458749 -0.121872  0.208748  0.361723  0.093351 -0.130329  0.359318
# 120018 -0.002008 -0.001913 -0.000680 -0.000761 -0.001244 -0.001835  0.001761
# 120019 -0.000326 -0.000279 -0.001968 -0.002086 -0.001505  0.000012  0.000026
# 120020  0.004111 -0.001919  0.004236 -0.000473  0.002308 -0.001240  0.000902
# 120021  0.002371 -0.000425 -0.000121  0.001057  0.001927 -0.003916  0.000686
# 120022 -0.003509  0.001243  0.000344  0.000291 -0.001708  0.000483  0.001307
# 120023  0.000455 -0.000566 -0.000537 -0.001077 -0.000149  0.002027  0.001148
# 120024  0.001162 -0.000252 -0.001367 -0.001936 -0.001968  0.002572  0.001977
# 120025 -0.030318  0.011887 -0.037853  0.019170 -0.007245 -0.011691 -0.008175
# 120026 -0.029046  0.017150 -0.033013  0.023608 -0.005191 -0.008450 -0.007212
# 120027  0.000458 -0.015141 -0.022406 -0.038168  0.003418 -0.016191  0.015130
# 120028  0.001730 -0.009878 -0.017566 -0.033730  0.005472 -0.012950  0.016093
# 120029 -0.005422  0.001505 -0.000316 -0.000251 -0.002745  0.000914 -0.000115
# ...          ...       ...       ...       ...       ...       ...       ...
# 149970 -0.084743  0.165690  0.192114 -0.259935 -0.227394  0.448420 -0.632913
# 149971 -0.322917  0.163579  0.412375 -0.540771  0.001915  0.132129 -0.835570
# 149972  0.379561 -0.307676  0.094375  0.295758  0.302409  0.248260  0.187446
# 149973  0.747084 -2.050952  2.266221  0.137084  0.495975  0.079067 -1.797177
# 149974 -0.256630 -0.708374  0.279304  0.666884 -0.274669 -0.205202  0.025995
# 149975 -0.362911  0.421453 -0.106483 -0.045970 -0.261304  0.290594  0.462121
# 149976  0.143275 -0.121684  0.294809  0.145798  0.738335  1.040921  0.412696
# 149977 -0.638648 -0.557849 -0.024490 -0.436468  0.377902 -0.483327  1.124917
# 149978 -0.005422  0.001505 -0.000316 -0.000251 -0.002745  0.000914 -0.000115
# 149979 -0.002008 -0.001913 -0.000680 -0.000761 -0.001244 -0.001835  0.001761
# 149980  0.001846  0.000206  0.001056 -0.001992  0.000336  0.000995 -0.000925
# 149981  0.007040  0.003596  0.003055  0.007635  0.006844 -0.005294 -0.010481
# 149982  0.001162 -0.000252 -0.001367 -0.001936 -0.001968  0.002572  0.001977
# 149983  0.663212 -0.168629  0.148838  0.019912 -0.114705 -0.076289 -0.051820
# 149984 -0.192058  0.576658  0.255451  0.570978 -0.285614  0.351376 -0.705734
# 149985 -0.084743  0.165690  0.192114 -0.259935 -0.227394  0.448420 -0.632913
# 149986 -0.280509  0.401237  0.433355  0.041030 -0.405103  0.462048 -0.857759
# 149987 -0.287905  0.370068  0.388510 -0.041483 -0.444894  0.454158 -0.848761
# 149988  0.078610  0.260914  0.380076 -0.035250 -0.594329  0.255885  0.071950
# 149989 -0.074889 -0.035336 -0.357072 -0.324749 -0.001159 -0.353072  0.327271
# 149990  0.398183  1.294990  0.518737  0.141372 -0.314673  0.755536 -1.784277
# 149991 -0.005422  0.001505 -0.000316 -0.000251 -0.002745  0.000914 -0.000115
# 149992  0.007040  0.003596  0.003055  0.007635  0.006844 -0.005294 -0.010481
# 149993  0.001162 -0.000252 -0.001367 -0.001936 -0.001968  0.002572  0.001977
# 149994 -0.256630 -0.708374  0.279304  0.666884 -0.274669 -0.205202  0.025995
# 149995  0.177950 -1.058502  1.522598  0.698995 -1.185990  0.250821  0.421950
# 149996 -0.201398 -0.516876  0.123852  0.289769 -0.546521  0.272499 -0.145772
# 149997 -0.916822 -0.539581 -0.549579  0.842409 -0.534719  0.429245  0.881746
# 149998  0.122494 -0.673246  0.593601 -0.270697  0.563712  0.062711  0.290998
# 149999 -0.078727 -0.595892  0.118163  0.127084  0.388030 -0.536889 -0.669633
#
#             V900
# 120000  0.203684
# 120001 -0.401595
# 120002  0.020977
# 120003 -0.006458
# 120004 -0.001262
# 120005  0.002765
# 120006 -0.003551
# 120007 -0.001870
# 120008  0.003898
# 120009  0.014158
# 120010  0.016954
# 120011 -0.002249
# 120012 -0.014263
# 120013 -0.011466
# 120014  0.015815
# 120015  0.018612
# 120016 -0.006458
# 120017 -0.123025
# 120018 -0.001262
# 120019 -0.001870
# 120020  0.003898
# 120021 -0.000515
# 120022  0.001658
# 120023  0.001122
# 120024 -0.001158
# 120025 -0.008768
# 120026 -0.005971
# 120027  0.047476
# 120028  0.050273
# 120029 -0.006458
# ...          ...
# 149970  0.196397
# 149971  0.317797
# 149972 -0.105581
# 149973 -0.450364
# 149974  1.164857
# 149975  0.436320
# 149976  0.005877
# 149977  1.054953
# 149978 -0.006458
# 149979 -0.001262
# 149980  0.002765
# 149981  0.013913
# 149982 -0.001158
# 149983  0.155191
# 149984  0.447218
# 149985  0.196397
# 149986  0.330722
# 149987  0.434899
# 149988  0.100483
# 149989 -1.116127
# 149990 -1.492323
# 149991 -0.006458
# 149992  0.013913
# 149993 -0.001158
# 149994  1.164857
# 149995 -0.119544
# 149996  0.458125
# 149997  0.237742
# 149998 -0.018396
# 149999 -0.544024
#
# [30000 rows x 900 columns]

# %%
y = label[60000:90000]

X = train

# %%
seed = 2017
np.random.seed(seed)

# %% [markdown]
# ### GALOIS parameters :
# #### 1. Isolation forest :
# Number of estimators=100, maximum samples=’automatic’, contamination=’legacy’, maximum features=1.0, bootstrap=False, n_jobs=None, behaviour=’old’, random_state=None, verbose=0, warm_start=False
# #### 2. LOF :
# number of neighbors=20, algorithm=’auto’, leaf size=30, metric=’minkowski’, p=2, metric parameters=None, contamination=’legacy’, novelty=False, n_jobs=None
# #### 3. OCSVM :
# kernel=’rbf’, degree=3, gamma=’auto_deprecated’, coef0=0.0, tol=0.001, nu=0.5, shrinking=True, cache_size=200, verbose=False, max_iter=-1, random_state=None

# %% [markdown]
# # Training

# %%
from mlens.ensemble import SuperLearner
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import IsolationForest
from sklearn.svm import SVC
from sklearn.neighbors import LocalOutlierFactor as LOF
from sklearn.svm import OneClassSVM as OCSVM

# --- Build ---
# Passing a scoring function will create cv scores during fitting
# the scorer should be a simple function accepting to vectors and returning a scalar
ensemble = SuperLearner(scorer=accuracy_score, random_state=seed, verbose=2)

# Build the first layer
# ensemble.add([RandomForestClassifier(random_state=seed), SVC()])

ensemble.add([IsolationForest(), LOF(novelty=True)])


# Attach the final meta estimator
# ensemble.add_meta(LogisticRegression())

ensemble.add_meta(OCSVM())

# Fit ensemble
ensemble.fit(X, y)
# Out:
# Fitting 2 layers
# Processing layer-1
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/neighbors/lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/neighbors/lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/neighbors/lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# done | 00:03:00
# Processing layer-2
# /anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# done | 00:00:11
# Fit complete                        | 00:03:12
#
# Predicting 2 layers
# Processing layer-1
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# done | 00:02:28
# Processing layer-2             done | 00:00:05
# Predict complete                    | 00:02:33
# Prediction score: 0.857

# %% [markdown]
# # Saving model

# %%
with open('saved_model','wb') as f:
    pickle.dump(ensemble,f)

# %% [markdown]
# # Predicting

# %%
# Predict
preds = ensemble.predict(test)

print("Prediction score: %.3f" % accuracy_score(preds, label[120000:150000]))
# Out:
# Predicting 2 layers
# Processing layer-1
# /anaconda3/lib/python3.7/site-packages/sklearn/ensemble/iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# done | 00:02:24
# Processing layer-2             done | 00:00:04
# Predict complete                    | 00:02:29
# Prediction score: 0.857

# %% [markdown]
# # Loading model

# %%
import pickle

loaded_model = pickle.load(open('saved_model', 'rb'))
    
# Predict
ensemble = loaded_model
# Out:
# [MLENS] backend: threading

# %% [markdown]
# ### Training and testing time :
# #### 1. Training :
# Layer 1 (IF & LOF) : 3:03 minutes
# Layer 2 (OCSVM) : 00:11 minutes
# #### 2. Testing :
# Layer 1 (IF & LOF) : 00:05 minutes
# Layer 2 (OCSVM) : 02:36 minutes

# %%
# print("Prediction score: %.3f" % accuracy_score(preds, y[9000:]))
# print("Prediction score: %.3f" % accuracy_score(preds, label[120000:150000]))
# preds
# ensemble.data
predictions = DataFrame(preds)
predictions[0].value_counts()
# tn, fp, fn, tp = confusion_matrix(label[120000:150000],preds).ravel()
tn, fp, fn, tp = confusion_matrix(label[120000:150000],predictions[0]).ravel()
tn, fp, fn, tp
# Out:
# (1, 4, 4287, 25708)

# %% [markdown]
# ## Test results :
# ##### 1. True negatives : 1
# ##### 2. False positives : 4
# ##### 3 False negatives : 4156
# ##### 4 True positives : 25839

# %%
predictions.columns = ['Results']
predictions = predictions.replace(1,'Normal')
predictions= predictions.replace(-1,'Malicious')
predictions
# Out:
#          Results
# 0         Normal
# 1         Normal
# 2         Normal
# 3         Normal
# 4         Normal
# 5         Normal
# 6         Normal
# 7         Normal
# 8         Normal
# 9         Normal
# 10        Normal
# 11        Normal
# 12        Normal
# 13        Normal
# 14        Normal
# 15        Normal
# 16        Normal
# 17     Malicious
# 18        Normal
# 19        Normal
# 20        Normal
# 21        Normal
# 22        Normal
# 23        Normal
# 24        Normal
# 25        Normal
# 26        Normal
# 27        Normal
# 28        Normal
# 29        Normal
# ...          ...
# 29970     Normal
# 29971     Normal
# 29972     Normal
# 29973     Normal
# 29974     Normal
# 29975  Malicious
# 29976     Normal
# 29977     Normal
# 29978     Normal
# 29979     Normal
# 29980     Normal
# 29981     Normal
# 29982     Normal
# 29983     Normal
# 29984  Malicious
# 29985     Normal
# 29986     Normal
# 29987     Normal
# 29988  Malicious
# 29989     Normal
# 29990     Normal
# 29991     Normal
# 29992     Normal
# 29993     Normal
# 29994     Normal
# 29995     Normal
# 29996     Normal
# 29997     Normal
# 29998     Normal
# 29999     Normal
#
# [30000 rows x 1 columns]

# %%
events_sub['Results'].value_counts()
# Out:
# Normal       25843
# Malicious     4157
# Name: Results, dtype: int64

# %%
ens = DataFrame(ensemble.data)
ens.columns = ['Score:Mean','Score:Std-deviation','Fit-time:Mean','Fit-time:Std-deviation','Pred-time:Mean','Pred-time:Std-deviation']
ens
# Out:
#                             Score:Mean  Score:Std-deviation  Fit-time:Mean  \
# layer-1/isolationforest       0.899933             0.001933      18.940814
# layer-1/localoutlierfactor    0.922267             0.006933      62.307853
#
#                             Fit-time:Std-deviation  Pred-time:Mean  \
# layer-1/isolationforest                   0.064284        8.436225
# layer-1/localoutlierfactor                1.658862       53.489037
#
#                             Pred-time:Std-deviation
# layer-1/isolationforest                    0.011556
# layer-1/localoutlierfactor                 0.552484

# %%
results = predictions
events_sub=events[:30000]
events_sub['Results']=results
events_sub
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Time                    SU                    DU      SC      DC  \
# 0      83473           C3075$@DOM1           C3075$@DOM1   C3075     TGT
# 1      83473           C3342$@DOM1           C3342$@DOM1    C586    C586
# 2      83473           C3684$@DOM1           C3684$@DOM1    C586    C586
# 3      83473           C3971$@DOM1           C3971$@DOM1   C3971   C3971
# 4      83473           C3971$@DOM1           C3971$@DOM1   C3971   C3971
# 5      83473           C3986$@DOM1           C3986$@DOM1    C528    C528
# 6      83473            C429$@DOM1            C429$@DOM1    C457    C457
# 7      83473           C4375$@DOM1           C4375$@DOM1   C4375    C457
# 8      83473           C4375$@DOM1           C4375$@DOM1    C457    C457
# 9      83473            C467$@DOM1            C467$@DOM1    C467    C467
# 10     83473            C467$@DOM1            C467$@DOM1    C467    C467
# 11     83473           C4782$@DOM1           C4782$@DOM1    C467    C467
# 12     83473           C4984$@DOM1           C4984$@DOM1    C529    C529
# 13     83473           C5097$@DOM1           C5097$@DOM1   C5097    C612
# 14     83473           C5102$@DOM1           C5102$@DOM1   C5102    C467
# 15     83473           C5429$@DOM1           C5429$@DOM1   C5429    C612
# 16     83473           C5429$@DOM1           C5429$@DOM1    C612    C612
# 17     83473            C553$@DOM1            C553$@DOM1    C553    C523
# 18     83473            C567$@DOM1            C567$@DOM1    C101    C101
# 19     83473            C567$@DOM1            C567$@DOM1   C1085   C1085
# 20     83473            C567$@DOM1            C567$@DOM1    C574    C101
# 21     83473            C585$@DOM1            C585$@DOM1    C585    C586
# 22     83473            C585$@DOM1            C585$@DOM1    C586    C586
# 23     83473            C599$@DOM1            C599$@DOM1    C101    C101
# 24     83473            C599$@DOM1            C599$@DOM1   C1619    C101
# 25     83473            C599$@DOM1            C599$@DOM1    C523    C523
# 26     83473           C6001$@DOM1           C6001$@DOM1     C10     C10
# 27     83473            C612$@DOM1            C612$@DOM1   C1521    C612
# 28     83473            C612$@DOM1            C612$@DOM1    C612    C612
# 29     83473            C644$@DOM1            C644$@DOM1    C644    C528
# ...      ...                   ...                   ...     ...     ...
# 29970  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C2577    C586
# 29971  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586    C586    C586
# 29972  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C6236    C586
# 29973  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586    C684    C586
# 29974  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C7693    C586
# 29975  83654  ANONYMOUS LOGON@C612  ANONYMOUS LOGON@C612   C8113    C612
# 29976  83654  ANONYMOUS LOGON@C625  ANONYMOUS LOGON@C625    C625    C625
# 29977  83654            C101$@DOM1            C101$@DOM1    C101    C988
# 29978  83654          C10101$@DOM1          C10101$@DOM1  C10101    C586
# 29979  83654            C104$@DOM1            C104$@DOM1    C105    C104
# 29980  83654           C1065$@DOM1           C1065$@DOM1   C1065   C1065
# 29981  83654           C1065$@DOM1           C1065$@DOM1   C1065   C1065
# 29982  83654          C10980$@DOM1          C10980$@DOM1  C10980  C10980
# 29983  83654          C10980$@DOM1          C10980$@DOM1  C10980    C529
# 29984  83654           C1114$@DOM1           C1114$@DOM1   C1115   C1114
# 29985  83654          C12122$@DOM1          C12122$@DOM1   C2106   C2106
# 29986  83654          C12949$@DOM1          C12949$@DOM1   C2106   C2106
# 29987  83654          C12981$@DOM1          C12981$@DOM1  C12981  C12981
# 29988  83654          C12981$@DOM1          C12981$@DOM1  C12981   C1640
# 29989  83654          C12981$@DOM1          C12981$@DOM1  C12981   C2106
# 29990  83654           C1328$@DOM1           C1328$@DOM1   C2106   C2106
# 29991  83654          C13386$@DOM1          C13386$@DOM1  C13386   C2106
# 29992  83654          C13386$@DOM1          C13386$@DOM1  C13386     TGT
# 29993  83654           C1381$@DOM1           C1381$@DOM1    C586    C586
# 29994  83654           C1388$@DOM1           C1388$@DOM1    C586    C586
# 29995  83654          C13992$@DOM1          C13992$@DOM1   C2106   C2106
# 29996  83654          C14042$@DOM1          C14042$@DOM1    C467    C467
# 29997  83654          C14042$@DOM1          C14042$@DOM1    C586    C586
# 29998  83654          C14042$@DOM1          C14042$@DOM1    C625    C625
# 29999  83654            C141$@DOM1            C141$@DOM1    C141    C528
#
#              AT       LT      AO       SF    Results
# 0             ?        ?     TGS  Success     Normal
# 1             ?  Network  LogOff  Success     Normal
# 2             ?  Network  LogOff  Success     Normal
# 3             ?  Network  LogOff  Success     Normal
# 4      Kerberos  Network   LogOn  Success     Normal
# 5             ?  Network  LogOff  Success     Normal
# 6             ?  Network  LogOff  Success     Normal
# 7      Kerberos  Network   LogOn  Success     Normal
# 8             ?  Network  LogOff  Success     Normal
# 9             ?  Network  LogOff  Success     Normal
# 10     Kerberos  Network   LogOn  Success     Normal
# 11            ?  Network  LogOff  Success     Normal
# 12            ?  Network  LogOff  Success     Normal
# 13     Kerberos  Network   LogOn  Success     Normal
# 14     Kerberos  Network   LogOn  Success     Normal
# 15     Kerberos  Network   LogOn  Success     Normal
# 16            ?  Network  LogOff  Success     Normal
# 17     Kerberos  Network   LogOn  Success  Malicious
# 18            ?  Network  LogOff  Success     Normal
# 19            ?  Network  LogOff  Success     Normal
# 20     Kerberos  Network   LogOn  Success     Normal
# 21     Kerberos  Network   LogOn  Success     Normal
# 22            ?  Network  LogOff  Success     Normal
# 23            ?  Network  LogOff  Success     Normal
# 24     Kerberos  Network   LogOn  Success     Normal
# 25            ?  Network  LogOff  Success     Normal
# 26            ?  Network  LogOff  Success     Normal
# 27     Kerberos  Network   LogOn  Success     Normal
# 28            ?  Network  LogOff  Success     Normal
# 29     Kerberos  Network   LogOn  Success     Normal
# ...         ...      ...     ...      ...        ...
# 29970      NTLM  Network   LogOn  Success     Normal
# 29971         ?  Network  LogOff  Success     Normal
# 29972      NTLM  Network   LogOn  Success     Normal
# 29973      NTLM  Network   LogOn  Success     Normal
# 29974      NTLM  Network   LogOn  Success     Normal
# 29975      NTLM  Network   LogOn  Success  Malicious
# 29976         ?  Network  LogOff  Success     Normal
# 29977  Kerberos  Network   LogOn  Success     Normal
# 29978  Kerberos  Network   LogOn  Success     Normal
# 29979         ?        ?     TGS  Success     Normal
# 29980         ?  Network  LogOff  Success     Normal
# 29981  Kerberos  Network   LogOn  Success     Normal
# 29982         ?        ?     TGS  Success     Normal
# 29983  Kerberos  Network   LogOn  Success     Normal
# 29984         ?        ?     TGS  Success  Malicious
# 29985         ?  Network  LogOff  Success     Normal
# 29986         ?  Network  LogOff  Success     Normal
# 29987         ?        ?     TGS  Success     Normal
# 29988         ?        ?     TGS  Success  Malicious
# 29989  Kerberos  Network   LogOn  Success     Normal
# 29990         ?  Network  LogOff  Success     Normal
# 29991  Kerberos  Network   LogOn  Success     Normal
# 29992         ?        ?     TGS  Success     Normal
# 29993         ?  Network  LogOff  Success     Normal
# 29994         ?  Network  LogOff  Success     Normal
# 29995         ?  Network  LogOff  Success     Normal
# 29996         ?  Network  LogOff  Success     Normal
# 29997         ?  Network  LogOff  Success     Normal
# 29998         ?  Network  LogOff  Success     Normal
# 29999      NTLM  Network   LogOn  Success     Normal
#
# [30000 rows x 10 columns]

# %%
events_sub.loc[events_sub['Results'] == 'Malicious']
# Out:
#         Time                     SU                     DU      SC      DC  \
# 17     83473             C553$@DOM1             C553$@DOM1    C553    C523
# 30     83473            C7348$@DOM1            C7348$@DOM1    C612    C612
# 34     83473             C743$@DOM1             C743$@DOM1    C743    C586
# 48     83473  NETWORK SERVICE@C3971  NETWORK SERVICE@C3971   C3971   C3971
# 63     83473             U3841@DOM1             U3841@DOM1   C3173   C3173
# 64     83473             U4665@DOM1           U4639@C11307  C11307  C11307
# 80     83473               U75@DOM1               U75@DOM1   C1710   C1710
# 81     83473               U87@DOM1               U87@DOM1   C1772   C1772
# 84     83474           C10351$@DOM1           C10351$@DOM1  C10351  C10351
# 85     83474           C10351$@DOM1           C10351$@DOM1  C10351  C10351
# 86     83474           C10351$@DOM1           C10351$@DOM1  C10351    C467
# 87     83474           C10351$@DOM1           C10351$@DOM1  C10351    C467
# 88     83474           C10351$@DOM1           C10351$@DOM1  C10351    C529
# 89     83474           C10351$@DOM1           C10351$@DOM1  C10351    C529
# 90     83474           C10351$@DOM1           C10351$@DOM1   C1798  C10351
# 99     83474             C104$@DOM1             C104$@DOM1    C105    C467
# 103    83474           C11120$@DOM1           C11120$@DOM1  C11120    C625
# 105    83474            C1148$@DOM1            C1148$@DOM1   C1148   C1065
# 110    83474            C1148$@DOM1            C1148$@DOM1    C612    C612
# 116    83474            C1235$@DOM1            C1235$@DOM1    C528    C528
# 117    83474            C1235$@DOM1            C1235$@DOM1    C612    C612
# 121    83474           C13350$@DOM1           C13350$@DOM1  C13350    C612
# 138    83474           C15552$@DOM1           C15552$@DOM1    C586    C586
# 139    83474            C1570$@DOM1            C1570$@DOM1   C1570   C1015
# 150    83474            C1827$@DOM1            C1827$@DOM1   C1828   C1828
# 153    83474            C1931$@DOM1            C1931$@DOM1    C529    C529
# 172    83474            C4782$@DOM1            C4782$@DOM1    C467    C467
# 176    83474            C5414$@DOM1            C5414$@DOM1   C1065   C1065
# 180    83474             C567$@DOM1             C567$@DOM1    C574    C553
# 186    83474             C599$@DOM1             C599$@DOM1   C1619   C1085
# ...      ...                    ...                    ...     ...     ...
# 29710  83652              U574@DOM1              U574@DOM1    C729    C586
# 29727  83653   ANONYMOUS LOGON@C586   ANONYMOUS LOGON@C586    C586    C586
# 29732  83653           C10739$@DOM1           C10739$@DOM1  C10739    C586
# 29746  83653           C12244$@DOM1           C12244$@DOM1  C12244    C467
# 29749  83653           C12244$@DOM1           C12244$@DOM1  C12244    C586
# 29764  83653            C1420$@DOM1            C1420$@DOM1   C1420   C1065
# 29765  83653            C1420$@DOM1            C1420$@DOM1   C1420   C1420
# 29770  83653            C1420$@DOM1            C1420$@DOM1   C1420    C612
# 29797  83653            C1583$@DOM1            C1583$@DOM1   C1583    C467
# 29799  83653            C1583$@DOM1            C1583$@DOM1   C1583    C528
# 29802  83653            C1583$@DOM1            C1583$@DOM1   C1583     TGT
# 29828  83653            C2223$@DOM1            C2223$@DOM1   C2224   C2224
# 29829  83653            C2223$@DOM1            C2223$@DOM1   C2224    C529
# 29831  83653            C2223$@DOM1            C2223$@DOM1    C529    C529
# 29834  83653            C2403$@DOM1            C2403$@DOM1   C2404   C2404
# 29845  83653            C2796$@DOM1            C2796$@DOM1    C586    C586
# 29847  83653            C3007$@DOM1            C3007$@DOM1    C528    C528
# 29850  83653            C3073$@DOM1            C3073$@DOM1   C3073    C625
# 29864  83653             C480$@DOM1             C480$@DOM1   C2106   C2106
# 29881  83653             C553$@DOM1             C553$@DOM1    C523    C523
# 29883  83653             C567$@DOM1             C567$@DOM1    C101    C101
# 29904  83653            C8225$@DOM1            C8225$@DOM1   C8225    C529
# 29925  83653            C9479$@DOM1            C9479$@DOM1    C586    C586
# 29926  83653             C950$@DOM1             C950$@DOM1   C2106   C2106
# 29931  83653             U1769@DOM1             U1769@DOM1   C2106   C2106
# 29942  83653             U3600@DOM1             U3600@DOM1   C9353    C625
# 29955  83653               U63@DOM1               U63@DOM1   C1755   C1755
# 29975  83654   ANONYMOUS LOGON@C612   ANONYMOUS LOGON@C612   C8113    C612
# 29984  83654            C1114$@DOM1            C1114$@DOM1   C1115   C1114
# 29988  83654           C12981$@DOM1           C12981$@DOM1  C12981   C1640
#
#               AT           LT       AO       SF    Results
# 17      Kerberos      Network    LogOn  Success  Malicious
# 30             ?      Network   LogOff  Success  Malicious
# 34      Kerberos      Network    LogOn  Success  Malicious
# 48     Negotiate      Service    LogOn  Success  Malicious
# 63             ?      Network   LogOff  Success  Malicious
# 64             ?            ?  AuthMap  Success  Malicious
# 80             ?  Interactive   LogOff  Success  Malicious
# 81             ?      Network   LogOff  Success  Malicious
# 84             ?            ?      TGS  Success  Malicious
# 85             ?      Network   LogOff  Success  Malicious
# 86             ?            ?      TGS  Success  Malicious
# 87      Kerberos      Network    LogOn  Success  Malicious
# 88             ?            ?      TGS  Success  Malicious
# 89      Kerberos      Network    LogOn  Success  Malicious
# 90      Kerberos      Network    LogOn  Success  Malicious
# 99      Kerberos      Network    LogOn  Success  Malicious
# 103     Kerberos      Network    LogOn  Success  Malicious
# 105     Kerberos      Network    LogOn  Success  Malicious
# 110            ?      Network   LogOff  Success  Malicious
# 116            ?      Network   LogOff  Success  Malicious
# 117            ?      Network   LogOff  Success  Malicious
# 121     Kerberos      Network    LogOn  Success  Malicious
# 138            ?      Network   LogOff  Success  Malicious
# 139         NTLM      Network    LogOn  Success  Malicious
# 150            ?            ?      TGT  Success  Malicious
# 153            ?      Network   LogOff  Success  Malicious
# 172            ?      Network   LogOff  Success  Malicious
# 176            ?      Network   LogOff  Success  Malicious
# 180     Kerberos      Network    LogOn  Success  Malicious
# 186     Kerberos      Network    LogOn  Success  Malicious
# ...          ...          ...      ...      ...        ...
# 29710   Kerberos      Network    LogOn  Success  Malicious
# 29727          ?      Network   LogOff  Success  Malicious
# 29732   Kerberos      Network    LogOn  Success  Malicious
# 29746   Kerberos      Network    LogOn  Success  Malicious
# 29749   Kerberos      Network    LogOn  Success  Malicious
# 29764   Kerberos      Network    LogOn  Success  Malicious
# 29765          ?            ?      TGS  Success  Malicious
# 29770          ?            ?      TGS  Success  Malicious
# 29797          ?            ?      TGS  Success  Malicious
# 29799   Kerberos      Network    LogOn  Success  Malicious
# 29802          ?            ?      TGS  Success  Malicious
# 29828          ?            ?      TGT  Success  Malicious
# 29829          ?            ?      TGS  Success  Malicious
# 29831          ?      Network   LogOff  Success  Malicious
# 29834          ?            ?      TGT  Success  Malicious
# 29845          ?      Network   LogOff  Success  Malicious
# 29847          ?      Network   LogOff  Success  Malicious
# 29850       NTLM      Network    LogOn     Fail  Malicious
# 29864          ?      Network   LogOff  Success  Malicious
# 29881          ?      Network   LogOff  Success  Malicious
# 29883          ?      Network   LogOff  Success  Malicious
# 29904       NTLM      Network    LogOn  Success  Malicious
# 29925          ?      Network   LogOff  Success  Malicious
# 29926          ?      Network   LogOff  Success  Malicious
# 29931          ?      Network   LogOff  Success  Malicious
# 29942   Kerberos      Network    LogOn  Success  Malicious
# 29955   Kerberos      Network    LogOn  Success  Malicious
# 29975       NTLM      Network    LogOn  Success  Malicious
# 29984          ?            ?      TGS  Success  Malicious
# 29988          ?            ?      TGS  Success  Malicious
#
# [4157 rows x 10 columns]
