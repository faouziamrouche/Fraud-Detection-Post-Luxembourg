# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix
from sklearn.datasets import load_iris
from pandas import DataFrame
import numpy as np
import pandas
import pickle

datas = pandas.read_csv('./PCs900_LosAlamos.csv', sep=',', chunksize=30000) 
label = pandas.read_csv('./Labels.csv', sep=',')
events = pandas.read_csv('./Events.csv', sep=',')

label = label['Label']
label = label.replace(['Normal'], 1)
label= label.replace(['Malicious'], -1)
j=0
test = 0

for i in datas :
    j=j+1
#     if j == 5 : continue
    if j == 3 :
        train = i
    if j == 5 : 
        test = i
        break

# %%
# label['Label'].value_counts()
label.value_counts()
# label.describe()
# np.unique(y)
# sub_test = test[:1]
# sub_test
# sub_test.to_json(r'sub_test_1.json')
train
# Out:
#                V1         V2         V3         V4         V5         V6  \
# 60000  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 60001  426.379446 -16.048053 -23.115494  -0.850990   3.475935   2.545945
# 60002  424.778191  -9.971357  19.660845   7.556989 -27.286316  -1.579386
# 60003  425.274063  -3.716544 -11.322449  16.435619 -27.717455  -2.370118
# 60004  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 60005  425.969482 -16.594488 -22.202901  -2.681745   6.971683  -0.474077
# 60006  425.567113 -14.273073 -21.384747  -0.458550   4.886783  -0.158619
# 60007  425.639531 -15.939426 -20.878705  -1.106218   5.718349 -11.065449
# 60008  425.521741 -23.202100  13.320512 -12.660927   6.614110  -0.444849
# 60009  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 60010  424.330577 -19.818776  11.878280  -8.959038   3.883214  -0.374622
# 60011  422.880015  30.131129  -4.464378  -7.182320   0.234028   0.252227
# 60012  423.434411  29.374470  -4.490521  -7.411975   0.295382  -0.250180
# 60013  422.948707  29.961557  -4.154237  -7.414292  -0.027311   0.643322
# 60014  422.981029  29.744084  -4.103788  -6.864512   0.127646   1.200784
# 60015  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 60016  425.271485 -13.247218 -18.465048   0.193684   2.792051  -1.471992
# 60017  425.270750 -23.672496  11.428520 -10.947172   4.421412   3.633013
# 60018  426.381351 -17.047706 -23.617200  -1.521476   5.705515   2.375717
# 60019  425.969482 -16.594488 -22.202901  -2.681745   6.971683  -0.474077
# 60020  425.639531 -15.939426 -20.878705  -1.106218   5.718349 -11.065449
# 60021  425.521741 -23.202100  13.320512 -12.660927   6.614110  -0.444849
# 60022  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 60023  426.379446 -16.048053 -23.115494  -0.850990   3.475935   2.545945
# 60024  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
# 60025  423.249434  29.713445  -3.927010  -7.353045   1.072505   1.226619
# 60026  422.627242  29.451519  -4.866565  -7.456879   0.380760   0.235257
# 60027  425.639531 -15.939426 -20.878705  -1.106218   5.718349 -11.065449
# 60028  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 60029  425.729733 -10.167308  18.904964   6.576651 -25.333966  -1.354833
# ...           ...        ...        ...        ...        ...        ...
# 89970  425.217706 -15.731785 -18.870492  -2.734367   5.502512  -0.772616
# 89971  425.412681 -15.361266 -19.142493  -1.415035   5.325256  -8.006478
# 89972  425.639531 -15.939426 -20.878705  -1.106218   5.718349 -11.065449
# 89973  425.521741 -23.202100  13.320512 -12.660927   6.614110  -0.444849
# 89974  425.364269 -21.863845  13.092933 -11.519172   6.032993 -12.684068
# 89975  426.085992  -3.437186 -11.293090  16.987290 -28.649172  -1.356700
# 89976  423.359955  29.815556  -4.245352  -7.447082   0.248292   0.476513
# 89977  424.524174  15.280412  25.033684  -5.407543   4.333647  -4.186367
#
# 89972  0.001307  0.001658
# 89973  0.001148  0.001122
# 89974  0.001977 -0.001158
# 89975 -0.013440  0.071159
# 89976 -0.076055  0.210471
# 89977 -0.000115 -0.006458
# 89978 -0.355077  0.067579
# 89979  0.001761 -0.001262
# 89980 -0.000925  0.002765
# 89981  0.003004 -0.006793
# 89982 -0.010481  0.013913
# 89983  0.000026 -0.001870
# 89984  0.001148  0.001122
# 89985  0.001977 -0.001158
# 89986  0.000649 -0.003061
# 89987 -0.027888 -0.018167
# 89988 -0.026925 -0.015370
# 89989 -0.093553  0.294655
# 89990 -0.000115 -0.006458
# 89991 -1.003774  0.298072
# 89992  0.001761 -0.001262
# 89993 -0.000925  0.002765
# 89994  0.003004 -0.006793
# 89995 -0.010481  0.013913
# 89996  0.000026 -0.001870
# 89997  0.000902  0.003898
# 89998  0.000686 -0.000515
# 89999 -0.005435  0.009559
#
# [30000 rows x 900 columns]

# %% [markdown]
# # Logistic PCA

# %%
y = label[60000:90000]

X = train

# %%
seed = 2017
np.random.seed(seed)

# %% [markdown]
# ### GALOIS parameters :
# #### 1. Isolation forest :
# Number of estimators=100, maximum samples=’automatic’, contamination=’legacy’, maximum features=1.0, bootstrap=False, n_jobs=None, behaviour=’old’, random_state=None, verbose=0, warm_start=False
# #### 2. LOF :
# number of neighbors=20, algorithm=’auto’, leaf size=30, metric=’minkowski’, p=2, metric parameters=None, contamination=’legacy’, novelty=False, n_jobs=None
# #### 3. OCSVM :
# kernel=’rbf’, degree=3, gamma=’auto_deprecated’, coef0=0.0, tol=0.001, nu=0.5, shrinking=True, cache_size=200, verbose=False, max_iter=-1, random_state=None

# %% [markdown]
# # Training

# %%
from mlens.ensemble import SuperLearner
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import IsolationForest
from sklearn.svm import SVC
from sklearn.neighbors import LocalOutlierFactor as LOF
from sklearn.svm import OneClassSVM as OCSVM

# --- Build ---
# Passing a scoring function will create cv scores during fitting
# the scorer should be a simple function accepting to vectors and returning a scalar
ensemble = SuperLearner(scorer=accuracy_score, random_state=seed, verbose=2)

# Build the first layer
# ensemble.add([RandomForestClassifier(random_state=seed), SVC()])

ensemble.add([IsolationForest(), LOF(novelty=True)])


# Attach the final meta estimator
# ensemble.add_meta(LogisticRegression())

ensemble.add_meta(OCSVM())

# Fit ensemble
ensemble.fit(X, y)
# Out:
# [MLENS] backend: threading
# Fitting 2 layers
# Processing layer-1
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:213: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:223: FutureWarning: behaviour="old" is deprecated and will be removed in version 0.22. Please use behaviour="new", which makes the decision_function change to match other anomaly detection algorithm API.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)
# done | 00:05:51
# Processing layer-2
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# done | 00:00:34
# Fit complete                        | 00:06:26
# SuperLearner(array_check=None, backend=None, folds=2,
#        layers=[Layer(backend='threading', dtype=<class 'numpy.float32'>, n_jobs=-1,
#    name='layer-1', propagate_features=None, raise_on_exception=True,
#    random_state=9787, shuffle=False,
#    stack=[Group(backend='threading', dtype=<class 'numpy.float32'>,
#    indexer=FoldIndex(X=None, folds=2, raise_on_ex...D17AF28>)],
#    n_jobs=-1, name='group-1', raise_on_exception=True, transformers=[])],
#    verbose=1)],
#        model_selection=False, n_jobs=None, raise_on_exception=True,
#        random_state=2017, sample_size=20,
#        scorer=<function accuracy_score at 0x000002AD1D17AF28>,
#        shuffle=False, verbose=2)

# %% [markdown]
# # Saving model

# %%
with open('saved_model','wb') as f:
    pickle.dump(ensemble,f)

# %% [markdown]
# # Predicting

# %%
# Predict
preds = ensemble.predict(test)

print("Prediction score: %.3f" % accuracy_score(preds, label[120000:150000]))
# Out:
# Predicting 2 layers
# Processing layer-1
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\iforest.py:417: DeprecationWarning: threshold_ attribute is deprecated in 0.20 and will be removed in 0.22.
#   " be removed in 0.22.", DeprecationWarning)
# done | 00:06:01
# Processing layer-2             done | 00:00:11
# Predict complete                    | 00:06:13
# Prediction score: 0.861

# %% [markdown]
# # Loading model

# %%
import pickle

loaded_model = pickle.load(open('saved_model', 'rb'))
    
# Predict
ensemble = loaded_model
# Out:
# [MLENS] backend: threading

# %% [markdown]
# ### Training and testing time :
# #### 1. Training :
# Layer 1 (IF & LOF) : 3:03 minutes
# Layer 2 (OCSVM) : 00:11 minutes
# #### 2. Testing :
# Layer 1 (IF & LOF) : 00:05 minutes
# Layer 2 (OCSVM) : 02:36 minutes

# %%
# print("Prediction score: %.3f" % accuracy_score(preds, y[9000:]))
# print("Prediction score: %.3f" % accuracy_score(preds, label[120000:150000]))
# preds
# ensemble.data
predictions = DataFrame(preds)
predictions[0].value_counts()
# tn, fp, fn, tp = confusion_matrix(label[120000:150000],preds).ravel()
tn, fp, fn, tp = confusion_matrix(label[120000:150000],predictions[0]).ravel()
tn, fp, fn, tp
# Out:
# (1, 4, 4173, 25822)

# %% [markdown]
# ## Test results :
# ##### 1. True negatives : 1
# ##### 2. False positives : 4
# ##### 3 False negatives : 4156
# ##### 4 True positives : 25839

# %%
predictions.columns = ['Results']
predictions = predictions.replace(1,'Normal')
predictions= predictions.replace(-1,'Malicious')
predictions
# Out:
#          Results
# 0         Normal
# 1         Normal
# 2         Normal
# 3         Normal
# 4         Normal
# 5         Normal
# 6         Normal
# 7         Normal
# 8         Normal
# 9         Normal
# 10        Normal
# 11        Normal
# 12        Normal
# 13        Normal
# 14        Normal
# 15        Normal
# 16        Normal
# 17     Malicious
# 18        Normal
# 19        Normal
# 20        Normal
# 21        Normal
# 22        Normal
# 23        Normal
# 24        Normal
# 25        Normal
# 26        Normal
# 27        Normal
# 28        Normal
# 29        Normal
# ...          ...
# 29970     Normal
# 29971     Normal
# 29972     Normal
# 29973     Normal
# 29974     Normal
# 29975  Malicious
# 29976     Normal
# 29977     Normal
# 29978     Normal
# 29979     Normal
# 29980     Normal
# 29981     Normal
# 29982     Normal
# 29983     Normal
# 29984  Malicious
# 29985     Normal
# 29986     Normal
# 29987     Normal
# 29988  Malicious
# 29989     Normal
# 29990     Normal
# 29991     Normal
# 29992     Normal
# 29993     Normal
# 29994     Normal
# 29995     Normal
# 29996     Normal
# 29997     Normal
# 29998     Normal
# 29999     Normal
#
# [30000 rows x 1 columns]

# %%
events_sub['Results'].value_counts()
# Out:
# Normal       25843
# Malicious     4157
# Name: Results, dtype: int64

# %%
ens = DataFrame(ensemble.data)
ens.columns = ['Score:Mean','Score:Std-deviation','Fit-time:Mean','Fit-time:Std-deviation','Pred-time:Mean','Pred-time:Std-deviation']
ens
# Out:
#                             Score:Mean  Score:Std-deviation  Fit-time:Mean  \
# layer-1/isolationforest       0.899933             0.001933      18.940814
# layer-1/localoutlierfactor    0.922267             0.006933      62.307853
#
#                             Fit-time:Std-deviation  Pred-time:Mean  \
# layer-1/isolationforest                   0.064284        8.436225
# layer-1/localoutlierfactor                1.658862       53.489037
#
#                             Pred-time:Std-deviation
# layer-1/isolationforest                    0.011556
# layer-1/localoutlierfactor                 0.552484

# %%
results = predictions
events_sub=events[:30000]
events_sub['Results']=results
events_sub
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         Time                    SU                    DU      SC      DC  \
# 0      83473           C3075$@DOM1           C3075$@DOM1   C3075     TGT
# 1      83473           C3342$@DOM1           C3342$@DOM1    C586    C586
# 2      83473           C3684$@DOM1           C3684$@DOM1    C586    C586
# 3      83473           C3971$@DOM1           C3971$@DOM1   C3971   C3971
# 4      83473           C3971$@DOM1           C3971$@DOM1   C3971   C3971
# 5      83473           C3986$@DOM1           C3986$@DOM1    C528    C528
# 6      83473            C429$@DOM1            C429$@DOM1    C457    C457
# 7      83473           C4375$@DOM1           C4375$@DOM1   C4375    C457
# 8      83473           C4375$@DOM1           C4375$@DOM1    C457    C457
# 9      83473            C467$@DOM1            C467$@DOM1    C467    C467
# 10     83473            C467$@DOM1            C467$@DOM1    C467    C467
# 11     83473           C4782$@DOM1           C4782$@DOM1    C467    C467
# 12     83473           C4984$@DOM1           C4984$@DOM1    C529    C529
# 13     83473           C5097$@DOM1           C5097$@DOM1   C5097    C612
# 14     83473           C5102$@DOM1           C5102$@DOM1   C5102    C467
# 15     83473           C5429$@DOM1           C5429$@DOM1   C5429    C612
# 16     83473           C5429$@DOM1           C5429$@DOM1    C612    C612
# 17     83473            C553$@DOM1            C553$@DOM1    C553    C523
# 18     83473            C567$@DOM1            C567$@DOM1    C101    C101
# 19     83473            C567$@DOM1            C567$@DOM1   C1085   C1085
# 20     83473            C567$@DOM1            C567$@DOM1    C574    C101
# 21     83473            C585$@DOM1            C585$@DOM1    C585    C586
# 22     83473            C585$@DOM1            C585$@DOM1    C586    C586
# 23     83473            C599$@DOM1            C599$@DOM1    C101    C101
# 24     83473            C599$@DOM1            C599$@DOM1   C1619    C101
# 25     83473            C599$@DOM1            C599$@DOM1    C523    C523
# 26     83473           C6001$@DOM1           C6001$@DOM1     C10     C10
# 27     83473            C612$@DOM1            C612$@DOM1   C1521    C612
# 28     83473            C612$@DOM1            C612$@DOM1    C612    C612
# 29     83473            C644$@DOM1            C644$@DOM1    C644    C528
# ...      ...                   ...                   ...     ...     ...
# 29970  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C2577    C586
# 29971  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586    C586    C586
# 29972  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C6236    C586
# 29973  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586    C684    C586
# 29974  83654  ANONYMOUS LOGON@C586  ANONYMOUS LOGON@C586   C7693    C586
# 29975  83654  ANONYMOUS LOGON@C612  ANONYMOUS LOGON@C612   C8113    C612
# 29976  83654  ANONYMOUS LOGON@C625  ANONYMOUS LOGON@C625    C625    C625
# 29977  83654            C101$@DOM1            C101$@DOM1    C101    C988
# 29978  83654          C10101$@DOM1          C10101$@DOM1  C10101    C586
# 29979  83654            C104$@DOM1            C104$@DOM1    C105    C104
# 29980  83654           C1065$@DOM1           C1065$@DOM1   C1065   C1065
# 29981  83654           C1065$@DOM1           C1065$@DOM1   C1065   C1065
# 29982  83654          C10980$@DOM1          C10980$@DOM1  C10980  C10980
# 29983  83654          C10980$@DOM1          C10980$@DOM1  C10980    C529
# 29984  83654           C1114$@DOM1           C1114$@DOM1   C1115   C1114
# 29985  83654          C12122$@DOM1          C12122$@DOM1   C2106   C2106
# 29986  83654          C12949$@DOM1          C12949$@DOM1   C2106   C2106
# 29987  83654          C12981$@DOM1          C12981$@DOM1  C12981  C12981
# 29988  83654          C12981$@DOM1          C12981$@DOM1  C12981   C1640
# 29989  83654          C12981$@DOM1          C12981$@DOM1  C12981   C2106
# 29990  83654           C1328$@DOM1           C1328$@DOM1   C2106   C2106
# 29991  83654          C13386$@DOM1          C13386$@DOM1  C13386   C2106
# 29992  83654          C13386$@DOM1          C13386$@DOM1  C13386     TGT
# 29993  83654           C1381$@DOM1           C1381$@DOM1    C586    C586
# 29994  83654           C1388$@DOM1           C1388$@DOM1    C586    C586
# 29995  83654          C13992$@DOM1          C13992$@DOM1   C2106   C2106
# 29996  83654          C14042$@DOM1          C14042$@DOM1    C467    C467
# 29997  83654          C14042$@DOM1          C14042$@DOM1    C586    C586
# 29998  83654          C14042$@DOM1          C14042$@DOM1    C625    C625
# 29999  83654            C141$@DOM1            C141$@DOM1    C141    C528
#
#              AT       LT      AO       SF    Results
# 0             ?        ?     TGS  Success     Normal
# 1             ?  Network  LogOff  Success     Normal
# 2             ?  Network  LogOff  Success     Normal
# 3             ?  Network  LogOff  Success     Normal
# 4      Kerberos  Network   LogOn  Success     Normal
# 5             ?  Network  LogOff  Success     Normal
# 6             ?  Network  LogOff  Success     Normal
# 7      Kerberos  Network   LogOn  Success     Normal
# 8             ?  Network  LogOff  Success     Normal
# 9             ?  Network  LogOff  Success     Normal
# 10     Kerberos  Network   LogOn  Success     Normal
# 11            ?  Network  LogOff  Success     Normal
# 12            ?  Network  LogOff  Success     Normal
# 13     Kerberos  Network   LogOn  Success     Normal
# 14     Kerberos  Network   LogOn  Success     Normal
# 15     Kerberos  Network   LogOn  Success     Normal
# 16            ?  Network  LogOff  Success     Normal
# 17     Kerberos  Network   LogOn  Success  Malicious
# 18            ?  Network  LogOff  Success     Normal
# 19            ?  Network  LogOff  Success     Normal
# 20     Kerberos  Network   LogOn  Success     Normal
# 21     Kerberos  Network   LogOn  Success     Normal
# 22            ?  Network  LogOff  Success     Normal
# 23            ?  Network  LogOff  Success     Normal
# 24     Kerberos  Network   LogOn  Success     Normal
# 25            ?  Network  LogOff  Success     Normal
# 26            ?  Network  LogOff  Success     Normal
# 27     Kerberos  Network   LogOn  Success     Normal
# 28            ?  Network  LogOff  Success     Normal
# 29     Kerberos  Network   LogOn  Success     Normal
# ...         ...      ...     ...      ...        ...
# 29970      NTLM  Network   LogOn  Success     Normal
# 29971         ?  Network  LogOff  Success     Normal
# 29972      NTLM  Network   LogOn  Success     Normal
# 29973      NTLM  Network   LogOn  Success     Normal
# 29974      NTLM  Network   LogOn  Success     Normal
# 29975      NTLM  Network   LogOn  Success  Malicious
# 29976         ?  Network  LogOff  Success     Normal
# 29977  Kerberos  Network   LogOn  Success     Normal
# 29978  Kerberos  Network   LogOn  Success     Normal
# 29979         ?        ?     TGS  Success     Normal
# 29980         ?  Network  LogOff  Success     Normal
# 29981  Kerberos  Network   LogOn  Success     Normal
# 29982         ?        ?     TGS  Success     Normal
# 29983  Kerberos  Network   LogOn  Success     Normal
# 29984         ?        ?     TGS  Success  Malicious
# 29985         ?  Network  LogOff  Success     Normal
# 29986         ?  Network  LogOff  Success     Normal
# 29987         ?        ?     TGS  Success     Normal
# 29988         ?        ?     TGS  Success  Malicious
# 29989  Kerberos  Network   LogOn  Success     Normal
# 29990         ?  Network  LogOff  Success     Normal
# 29991  Kerberos  Network   LogOn  Success     Normal
# 29992         ?        ?     TGS  Success     Normal
# 29993         ?  Network  LogOff  Success     Normal
# 29994         ?  Network  LogOff  Success     Normal
# 29995         ?  Network  LogOff  Success     Normal
# 29996         ?  Network  LogOff  Success     Normal
# 29997         ?  Network  LogOff  Success     Normal
# 29998         ?  Network  LogOff  Success     Normal
# 29999      NTLM  Network   LogOn  Success     Normal
#
# [30000 rows x 10 columns]

# %%
events_sub.loc[events_sub['Results'] == 'Malicious']
# Out:
#         Time                     SU                     DU      SC      DC  \
# 17     83473             C553$@DOM1             C553$@DOM1    C553    C523
# 30     83473            C7348$@DOM1            C7348$@DOM1    C612    C612
# 34     83473             C743$@DOM1             C743$@DOM1    C743    C586
# 48     83473  NETWORK SERVICE@C3971  NETWORK SERVICE@C3971   C3971   C3971
# 63     83473             U3841@DOM1             U3841@DOM1   C3173   C3173
# 64     83473             U4665@DOM1           U4639@C11307  C11307  C11307
# 80     83473               U75@DOM1               U75@DOM1   C1710   C1710
# 81     83473               U87@DOM1               U87@DOM1   C1772   C1772
# 84     83474           C10351$@DOM1           C10351$@DOM1  C10351  C10351
# 85     83474           C10351$@DOM1           C10351$@DOM1  C10351  C10351
# 86     83474           C10351$@DOM1           C10351$@DOM1  C10351    C467
# 87     83474           C10351$@DOM1           C10351$@DOM1  C10351    C467
# 88     83474           C10351$@DOM1           C10351$@DOM1  C10351    C529
# 89     83474           C10351$@DOM1           C10351$@DOM1  C10351    C529
# 90     83474           C10351$@DOM1           C10351$@DOM1   C1798  C10351
# 99     83474             C104$@DOM1             C104$@DOM1    C105    C467
# 103    83474           C11120$@DOM1           C11120$@DOM1  C11120    C625
# 105    83474            C1148$@DOM1            C1148$@DOM1   C1148   C1065
# 110    83474            C1148$@DOM1            C1148$@DOM1    C612    C612
# 116    83474            C1235$@DOM1            C1235$@DOM1    C528    C528
# 117    83474            C1235$@DOM1            C1235$@DOM1    C612    C612
# 121    83474           C13350$@DOM1           C13350$@DOM1  C13350    C612
# 138    83474           C15552$@DOM1           C15552$@DOM1    C586    C586
# 139    83474            C1570$@DOM1            C1570$@DOM1   C1570   C1015
# 150    83474            C1827$@DOM1            C1827$@DOM1   C1828   C1828
# 153    83474            C1931$@DOM1            C1931$@DOM1    C529    C529
# 172    83474            C4782$@DOM1            C4782$@DOM1    C467    C467
# 176    83474            C5414$@DOM1            C5414$@DOM1   C1065   C1065
# 180    83474             C567$@DOM1             C567$@DOM1    C574    C553
# 186    83474             C599$@DOM1             C599$@DOM1   C1619   C1085
# ...      ...                    ...                    ...     ...     ...
# 29710  83652              U574@DOM1              U574@DOM1    C729    C586
# 29727  83653   ANONYMOUS LOGON@C586   ANONYMOUS LOGON@C586    C586    C586
# 29732  83653           C10739$@DOM1           C10739$@DOM1  C10739    C586
# 29746  83653           C12244$@DOM1           C12244$@DOM1  C12244    C467
# 29749  83653           C12244$@DOM1           C12244$@DOM1  C12244    C586
# 29764  83653            C1420$@DOM1            C1420$@DOM1   C1420   C1065
# 29765  83653            C1420$@DOM1            C1420$@DOM1   C1420   C1420
# 29770  83653            C1420$@DOM1            C1420$@DOM1   C1420    C612
# 29797  83653            C1583$@DOM1            C1583$@DOM1   C1583    C467
# 29799  83653            C1583$@DOM1            C1583$@DOM1   C1583    C528
# 29802  83653            C1583$@DOM1            C1583$@DOM1   C1583     TGT
# 29828  83653            C2223$@DOM1            C2223$@DOM1   C2224   C2224
# 29829  83653            C2223$@DOM1            C2223$@DOM1   C2224    C529
# 29831  83653            C2223$@DOM1            C2223$@DOM1    C529    C529
# 29834  83653            C2403$@DOM1            C2403$@DOM1   C2404   C2404
# 29845  83653            C2796$@DOM1            C2796$@DOM1    C586    C586
# 29847  83653            C3007$@DOM1            C3007$@DOM1    C528    C528
# 29850  83653            C3073$@DOM1            C3073$@DOM1   C3073    C625
# 29864  83653             C480$@DOM1             C480$@DOM1   C2106   C2106
# 29881  83653             C553$@DOM1             C553$@DOM1    C523    C523
# 29883  83653             C567$@DOM1             C567$@DOM1    C101    C101
# 29904  83653            C8225$@DOM1            C8225$@DOM1   C8225    C529
# 29925  83653            C9479$@DOM1            C9479$@DOM1    C586    C586
# 29926  83653             C950$@DOM1             C950$@DOM1   C2106   C2106
# 29931  83653             U1769@DOM1             U1769@DOM1   C2106   C2106
# 29942  83653             U3600@DOM1             U3600@DOM1   C9353    C625
# 29955  83653               U63@DOM1               U63@DOM1   C1755   C1755
# 29975  83654   ANONYMOUS LOGON@C612   ANONYMOUS LOGON@C612   C8113    C612
# 29984  83654            C1114$@DOM1            C1114$@DOM1   C1115   C1114
# 29988  83654           C12981$@DOM1           C12981$@DOM1  C12981   C1640
#
#               AT           LT       AO       SF    Results
# 17      Kerberos      Network    LogOn  Success  Malicious
# 30             ?      Network   LogOff  Success  Malicious
# 34      Kerberos      Network    LogOn  Success  Malicious
# 48     Negotiate      Service    LogOn  Success  Malicious
# 63             ?      Network   LogOff  Success  Malicious
# 64             ?            ?  AuthMap  Success  Malicious
# 80             ?  Interactive   LogOff  Success  Malicious
# 81             ?      Network   LogOff  Success  Malicious
# 84             ?            ?      TGS  Success  Malicious
# 85             ?      Network   LogOff  Success  Malicious
# 86             ?            ?      TGS  Success  Malicious
# 87      Kerberos      Network    LogOn  Success  Malicious
# 88             ?            ?      TGS  Success  Malicious
# 89      Kerberos      Network    LogOn  Success  Malicious
# 90      Kerberos      Network    LogOn  Success  Malicious
# 99      Kerberos      Network    LogOn  Success  Malicious
# 103     Kerberos      Network    LogOn  Success  Malicious
# 105     Kerberos      Network    LogOn  Success  Malicious
# 110            ?      Network   LogOff  Success  Malicious
# 116            ?      Network   LogOff  Success  Malicious
# 117            ?      Network   LogOff  Success  Malicious
# 121     Kerberos      Network    LogOn  Success  Malicious
# 138            ?      Network   LogOff  Success  Malicious
# 139         NTLM      Network    LogOn  Success  Malicious
# 150            ?            ?      TGT  Success  Malicious
# 153            ?      Network   LogOff  Success  Malicious
# 172            ?      Network   LogOff  Success  Malicious
# 176            ?      Network   LogOff  Success  Malicious
# 180     Kerberos      Network    LogOn  Success  Malicious
# 186     Kerberos      Network    LogOn  Success  Malicious
# ...          ...          ...      ...      ...        ...
# 29710   Kerberos      Network    LogOn  Success  Malicious
# 29727          ?      Network   LogOff  Success  Malicious
# 29732   Kerberos      Network    LogOn  Success  Malicious
# 29746   Kerberos      Network    LogOn  Success  Malicious
# 29749   Kerberos      Network    LogOn  Success  Malicious
# 29764   Kerberos      Network    LogOn  Success  Malicious
# 29765          ?            ?      TGS  Success  Malicious
# 29770          ?            ?      TGS  Success  Malicious
# 29797          ?            ?      TGS  Success  Malicious
# 29799   Kerberos      Network    LogOn  Success  Malicious
# 29802          ?            ?      TGS  Success  Malicious
# 29828          ?            ?      TGT  Success  Malicious
# 29829          ?            ?      TGS  Success  Malicious
# 29831          ?      Network   LogOff  Success  Malicious
# 29834          ?            ?      TGT  Success  Malicious
# 29845          ?      Network   LogOff  Success  Malicious
# 29847          ?      Network   LogOff  Success  Malicious
# 29850       NTLM      Network    LogOn     Fail  Malicious
# 29864          ?      Network   LogOff  Success  Malicious
# 29881          ?      Network   LogOff  Success  Malicious
# 29883          ?      Network   LogOff  Success  Malicious
# 29904       NTLM      Network    LogOn  Success  Malicious
# 29925          ?      Network   LogOff  Success  Malicious
# 29926          ?      Network   LogOff  Success  Malicious
# 29931          ?      Network   LogOff  Success  Malicious
# 29942   Kerberos      Network    LogOn  Success  Malicious
# 29955   Kerberos      Network    LogOn  Success  Malicious
# 29975       NTLM      Network    LogOn  Success  Malicious
# 29984          ?            ?      TGS  Success  Malicious
# 29988          ?            ?      TGS  Success  Malicious
#
# [4157 rows x 10 columns]
